# %% [markdown]
# <a href="https://colab.research.google.com/github/abhishek-chaudhary26/ocr/blob/main/OCR_Code.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !pip install pytesseract

# %%
from PIL import Image
import pandas as pd
import numpy as np
import seaborn as sns
import pytesseract as tess

# %%
df_test = pd.read_csv('/content/drive/MyDrive/datasets/ocr_dataset/CSV/written_name_test.csv')
df_train = pd.read_csv('/content/drive/MyDrive/datasets/ocr_dataset/CSV/written_name_train.csv')
df_validation = pd.read_csv('/content/drive/MyDrive/datasets/ocr_dataset/CSV/written_name_validation.csv')

# %%
df_test.head()
# Out:
#         FILENAME  IDENTITY
# 0  TEST_0001.jpg     KEVIN
# 1  TEST_0002.jpg  CLOTAIRE
# 2  TEST_0003.jpg      LENA
# 3  TEST_0004.jpg     JULES
# 4  TEST_0005.jpg   CHERPIN
